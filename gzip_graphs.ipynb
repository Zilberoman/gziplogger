# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
lines_count = [10, 100, 1000, 10000, 100000, 1000000, 10000000]
print(lines_count)
# Out:
# [10, 100, 1000, 10000, 100000, 1000000, 10000000]

# %%
plt.title('PC; 1 thread')
plt.xlabel('count of lines')
plt.ylabel('Time(ms)')

rollingFileAppender_vals = [29, 118, 354, 1337, 7666, 68285, 721781]
rollingFileAppenderWithGz_vals = [28, 103, 332, 1392, 7653, 70831, 822465]
gzipRollingFileAppender_vals = [20, 70, 221, 666, 3676, 27837, 259606]  

plt.plot(lines_count, rollingFileAppender_vals, color = 'blue', linestyle = 'solid', label = 'rollingFileAppender')
plt.plot(lines_count, rollingFileAppenderWithGz_vals, color = 'green', linestyle = 'solid', label = 'rollingFileAppenderWithGz')
plt.plot(lines_count, gzipRollingFileAppender_vals, color = 'red', linestyle = 'solid', label = 'gzipRollingFileAppender')
plt.legend(loc = 'upper right');

# %%
plt.title('PC; 8 threads')
plt.xlabel('count of lines')
plt.ylabel('Time(ms)')

rollingFileAppender_vals = [32, 39, 51, 79, 520, 6789, 69589]
rollingFileAppenderWithGz_vals = [33, 40, 50, 93, 368, 6321, 64790]
gzipRollingFileAppender_vals = [35, 35, 46, 86, 383, 4867, 49887]  

plt.plot(lines_count, rollingFileAppender_vals, color = 'blue', linestyle = 'solid', label = 'rollingFileAppender')
plt.plot(lines_count, rollingFileAppenderWithGz_vals, color = 'green', linestyle = 'solid', label = 'rollingFileAppenderWithGz')
plt.plot(lines_count, gzipRollingFileAppender_vals, color = 'red', linestyle = 'solid', label = 'gzipRollingFileAppender')
plt.legend(loc = 'upper right');

# %%
plt.title('PC; 4 threads')
plt.xlabel('count of lines')
plt.ylabel('Time(ms)')

rollingFileAppender_vals = [28, 25, 42, 117, 383, 11847, 118470]
rollingFileAppenderWithGz_vals = [22, 27, 44, 138, 362, 10235, 102346]
gzipRollingFileAppender_vals = [21, 32, 31, 74, 512, 6003, 60026] 

plt.plot(lines_count, rollingFileAppender_vals, color = 'blue', linestyle = 'solid', label = 'rollingFileAppender')
plt.plot(lines_count, rollingFileAppenderWithGz_vals, color = 'green', linestyle = 'solid', label = 'rollingFileAppenderWithGz')
plt.plot(lines_count, gzipRollingFileAppender_vals, color = 'red', linestyle = 'solid', label = 'gzipRollingFileAppender')
plt.legend(loc = 'upper right');

# %%
plt.title('Server; 1 thread')
plt.xlabel('count of lines')
plt.ylabel('Time(ms)')

rollingFileAppender_vals = [27, 90, 373, 1715, 15774, 127162, 1032955]
rollingFileAppenderWithGz_vals = [32, 71, 313, 1450, 11325, 85241, 911608]
gzipRollingFileAppender_vals = [24, 51, 141, 511, 2506, 20752, 192734] 

plt.plot(lines_count, rollingFileAppender_vals, color = 'blue', linestyle = 'solid', label = 'rollingFileAppender')
plt.plot(lines_count, rollingFileAppenderWithGz_vals, color = 'green', linestyle = 'solid', label = 'rollingFileAppenderWithGz')
plt.plot(lines_count, gzipRollingFileAppender_vals, color = 'red', linestyle = 'solid', label = 'gzipRollingFileAppender');
plt.legend(loc = 'upper right');

# %%
plt.title('Server; 8 threads')
plt.xlabel('count of lines')
plt.ylabel('Time(ms)')

rollingFileAppender_vals = [119, 109, 129, 251, 1080, 10820, 108202]
rollingFileAppenderWithGz_vals = [110, 109, 131, 175, 529, 6292, 62920]
gzipRollingFileAppender_vals = [61, 59, 67, 112, 383, 5810, 58104] 

plt.plot(lines_count, rollingFileAppender_vals, color = 'blue', linestyle = 'solid', label = 'rollingFileAppender')
plt.plot(lines_count, rollingFileAppenderWithGz_vals, color = 'green', linestyle = 'solid', label = 'rollingFileAppenderWithGz')
plt.plot(lines_count, gzipRollingFileAppender_vals, color = 'red', linestyle = 'solid', label = 'gzipRollingFileAppender');
plt.legend(loc = 'upper right');

# %%
plt.title('Server; 4 threads')
plt.xlabel('count of lines')
plt.ylabel('Time(ms)')

rollingFileAppender_vals = [94, 85, 117, 248, 1250, 11692, 117340]
rollingFileAppenderWithGz_vals = [85, 86, 120, 172, 632, 6824, 68193]
gzipRollingFileAppender_vals = [46, 46, 61, 111, 458, 6296, 62964] 

plt.plot(lines_count, rollingFileAppender_vals, color = 'blue', linestyle = 'solid', label = 'rollingFileAppender')
plt.plot(lines_count, rollingFileAppenderWithGz_vals, color = 'green', linestyle = 'solid', label = 'rollingFileAppenderWithGz')
plt.plot(lines_count, gzipRollingFileAppender_vals, color = 'red', linestyle = 'solid', label = 'gzipRollingFileAppender');
plt.legend(loc = 'upper right');
